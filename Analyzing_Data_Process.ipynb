# %% [markdown]
# <a href="https://colab.research.google.com/github/murphyslaw2781/DATA---Data_Analysis/blob/main/Analyzing_Data_Process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1.

# %% [markdown]
# Import libraries that speed up analysis!
# ```
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
#
# %matplotlib inline
#
# ```
# `np` `pd` `plt` are extremely common aliases but can be whatever you want.
#
# `%matplotlib inline` is a magic command that makes the plots generated by matplotlib show into the IPython shell that we are running and not in a separate output window

# %% [markdown]
# # Step 2.

# %% [markdown]
# Load your data, typically it is in a CSV format.
#
# You will use Pandas to load it into a `Dataframe` a special data structures tool.
#
# A `Dataframe` is a visual CSV like representation but has enforced data types.
#
# ```
# dataframe_name = pd.read_csv(
#     'file/location.csv',
#     parse_dates=['Date'])
#
# ```
# To read the date column correctly, we can use the argument parse_dates to specify a list of date columns. Above is the column name 'Date'.
#
# Ways to use `parse_dates`
# 1. Reading date columns from a CSV file
#   ex) `parse_dates=['date']`
# 2. Day first format (DD/MM, DD MM or, DD-MM)
#   ex)
#   ```
#   pd.read_csv('data/data_1.csv',
#               parse_dates=['date'],
#               dayfirst=True)
#   ```
# 3. Combining multiple columns to a datetime
#   ex)
#   ```
#   pd.read_csv('data/data_4.csv',
#                  parse_dates=[['year', 'month', 'day']])
#   ```
# 4. Customizing a date parser
#   ex)
#   ```
#   from datetime import datetime
#
#   custom_date_parser = lambda x: datetime.strptime(x, "%Y-%d-%m %H:%M:%S")
#
#   df = pd.read_csv('data/data_6.csv',
#                  parse_dates=['date'],
#                 date_parser=custom_date_parser)
#   ```

# %% [markdown]
# # Step 3.

# %% [markdown]
# ## Get a glance at your data.
# Here are starter methods:
#
# `dataframe.head()` - Shows the top of your dataframe
#
# `dataframe.shape()` - Counts Rows and Columns
#
# `dataframe.info()` - This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
#
# `dataframe.describe()` - Descriptive statistics - include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values

# %% [markdown]
# # Step 4.

# %% [markdown]
# ## Numerical Analysis
#
# Begin by looking at indivudual columns for numerical analysis
# ex)
# `dataframe['column_name'].describe()`
# `dataframe['column_name'].mean()`
# `dataframe['column_name'].median()`
# `dataframe['column_name'].value_counts()`
# `dataframe['column_name'].unique()`
#
# ## Plotting Your Analysis with Pandas using Matplotlib
# ex)
# *Kind = Chart Type*
# `dataframe['Column'].plot(kind='kde', figsize=(14,6))`
# `dataframe['Column'].plot(kind='box', vert=False, figsize=(14,6))`
# `dataframe['Column'].plot(kind='hist', bins=30, figsize=(14,6))`
# `dataframe['Column'].value_counts().plot(kind='pie', figsize=(6,6))`
# `dataframe['Column'].value_counts().plot(kind='bar', figsize=(14,6))`
# `dataframe.plot(kind='scatter', x='Column', y='Column', figsize=(6,6))`
#
#
# You can always go way more in depth - but this is a starting point for process!

# %% [markdown]
# # Step 5.
#
# ## Categorical Analysis

# %% [markdown]
# # Step 6.
#
# ## Look for Correlation (Relationships)
